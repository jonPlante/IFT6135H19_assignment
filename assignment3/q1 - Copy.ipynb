# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8e119d64-d16e-47d8-8aa0-7e0b6bec1f32" name="files[]" multiple disabled />
#      <output id="result-8e119d64-d16e-47d8-8aa0-7e0b6bec1f32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving samplers.py to samplers.py
# {'samplers.py': b"import numpy as np\r\nimport random\r\n\r\n\r\ndef distribution1(x, batch_size=512):\r\n    # Distribution defined as (x, U(0,1)). Can be used for question 3\r\n    while True:\r\n        yield(np.array([(x, random.uniform(0, 1)) for _ in range(batch_size)]))\r\n\r\n\r\ndef distribution2(batch_size=512):\r\n    # High dimension uniform distribution\r\n    while True:\r\n        yield(np.random.uniform(0, 1, (batch_size, 2)))\r\n\r\n\r\ndef distribution3(batch_size=512):\r\n    # 1D gaussian distribution\r\n    while True:\r\n        yield(np.random.normal(0, 1, (batch_size, 1)))\r\n\r\ne = lambda x: np.exp(x)\r\ntanh = lambda x: (e(x) - e(-x)) / (e(x)+e(-x))\r\ndef distribution4(batch_size=1):\r\n    # arbitrary sampler\r\n    f = lambda x: tanh(x*2+1) + x*0.75\r\n    while True:\r\n        yield(f(np.random.normal(0, 1, (batch_size, 1))))\r\n\r\n\r\n\r\nif __name__ == '__main__':\r\n    # Example of usage\r\n    dist = iter(distribution1(0, 100))\r\n    samples = next(dist)\r\n"}

# %%
from samplers import *

import numpy as np
import sklearn
import sklearn.metrics
import scipy
import torch
from torch import nn
import torch.nn.functional as F
from matplotlib import pyplot as plt

# %%
# Use the GPU if you have one
if torch.cuda.is_available():
    print("Using the GPU")
    device = torch.device("cuda") 
else:
    print("WARNING: You are about to run on cpu, and this will likely run out \
      of memory. \n You can try setting batch_size=1 to reduce memory usage")
    device = torch.device("cpu")
# Out:
# Using the GPU

# %%
def JSD(Dx,Dy):
  return np.log(2) + 0.5 * torch.mean(torch.log(Dx)) + 0.5 * torch.mean(torch.log(1 - Dy))

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(2, 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, 1)
    
    def forward(self, x):
#         x = x.view(-1, 512)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x
    
    def name(self):
        return "MLP"

# %%
phi=np.round(np.linspace(-1,1,21),2)
js_d=np.zeros(phi.shape)
n_epochs = 100000
lr = 0.001
for i in range(len(phi)):
  print('Training discriminator for phi: ' + str(phi[i])+'\n')
  D = MLP().to(device)
  optimizer = torch.optim.SGD(D.parameters(), lr=lr)
  for epoch in range(n_epochs):
    x_d = torch.FloatTensor(next(distribution1(0))).to(device)
    y_g = torch.FloatTensor(next(distribution1(phi[i]))).to(device)
    optimizer.zero_grad()
    Dx=D(x_d)
    Dy=D(y_g)
    loss =-JSD(Dx,Dy)
    loss.backward()
    optimizer.step()
    if epoch % 5000 == 0:
      print('phi : ' + str(phi[i]) + ', epoch: ' + str(epoch) +', loss: '+str(-loss.cpu().data.numpy()))
  js_d[i]=-loss.cpu().data.numpy()
    
print('\nDone All training')
# Out:
# Training discriminator for phi: -1.0
#
# phi : -1.0, epoch: 0, loss: 0.040958464
# phi : -1.0, epoch: 5000, loss: 0.584518
# phi : -1.0, epoch: 10000, loss: 0.6697448
# phi : -1.0, epoch: 15000, loss: 0.68236125
# phi : -1.0, epoch: 20000, loss: 0.6863661
# phi : -1.0, epoch: 25000, loss: 0.6886135
# phi : -1.0, epoch: 30000, loss: 0.6897278
# phi : -1.0, epoch: 35000, loss: 0.69041246
# phi : -1.0, epoch: 40000, loss: 0.6908667
# phi : -1.0, epoch: 45000, loss: 0.6912864
# phi : -1.0, epoch: 50000, loss: 0.6915384
# phi : -1.0, epoch: 55000, loss: 0.6916952
# phi : -1.0, epoch: 60000, loss: 0.6918922
# phi : -1.0, epoch: 65000, loss: 0.6919949
# phi : -1.0, epoch: 70000, loss: 0.69211286
# phi : -1.0, epoch: 75000, loss: 0.6922356
# phi : -1.0, epoch: 80000, loss: 0.6923215
# phi : -1.0, epoch: 85000, loss: 0.6923475
# phi : -1.0, epoch: 90000, loss: 0.6924025
# phi : -1.0, epoch: 95000, loss: 0.69248533
# Training discriminator for phi: -0.9
#
# phi : -0.9, epoch: 0, loss: -0.013471425
# phi : -0.9, epoch: 5000, loss: 0.2992115
# phi : -0.9, epoch: 10000, loss: 0.6186131
# phi : -0.9, epoch: 15000, loss: 0.6694436
# phi : -0.9, epoch: 20000, loss: 0.6812172
# phi : -0.9, epoch: 25000, loss: 0.68562967
# phi : -0.9, epoch: 30000, loss: 0.6878964
# phi : -0.9, epoch: 35000, loss: 0.68917656
# phi : -0.9, epoch: 40000, loss: 0.68999463
# phi : -0.9, epoch: 45000, loss: 0.69054276
# phi : -0.9, epoch: 50000, loss: 0.6909608
# phi : -0.9, epoch: 55000, loss: 0.6912632
# phi : -0.9, epoch: 60000, loss: 0.6915199
# phi : -0.9, epoch: 65000, loss: 0.69168717
# phi : -0.9, epoch: 70000, loss: 0.69185466
# phi : -0.9, epoch: 75000, loss: 0.6919749
# phi : -0.9, epoch: 80000, loss: 0.6920796
# phi : -0.9, epoch: 85000, loss: 0.69216365
# phi : -0.9, epoch: 90000, loss: 0.69224715
# phi : -0.9, epoch: 95000, loss: 0.69231385
# Training discriminator for phi: -0.8
#
# phi : -0.8, epoch: 0, loss: 0.005271733
# phi : -0.8, epoch: 5000, loss: 0.39626798
# phi : -0.8, epoch: 10000, loss: 0.65099597
# phi : -0.8, epoch: 15000, loss: 0.677717
# phi : -0.8, epoch: 20000, loss: 0.6846081
# phi : -0.8, epoch: 25000, loss: 0.6874599
# phi : -0.8, epoch: 30000, loss: 0.68896705
# phi : -0.8, epoch: 35000, loss: 0.68997985
# phi : -0.8, epoch: 40000, loss: 0.6905534
# phi : -0.8, epoch: 45000, loss: 0.690978
# phi : -0.8, epoch: 50000, loss: 0.6913032
# phi : -0.8, epoch: 55000, loss: 0.6915275
# phi : -0.8, epoch: 60000, loss: 0.691724
# phi : -0.8, epoch: 65000, loss: 0.6918772
# phi : -0.8, epoch: 70000, loss: 0.6920027
# phi : -0.8, epoch: 75000, loss: 0.6921137
# phi : -0.8, epoch: 80000, loss: 0.6921987
# phi : -0.8, epoch: 85000, loss: 0.6922695
# phi : -0.8, epoch: 90000, loss: 0.69233525
# phi : -0.8, epoch: 95000, loss: 0.6923925
# Training discriminator for phi: -0.7
#
# phi : -0.7, epoch: 0, loss: 0.012439638
# phi : -0.7, epoch: 5000, loss: 0.30413347
# phi : -0.7, epoch: 10000, loss: 0.628211
# phi : -0.7, epoch: 15000, loss: 0.67162544
# phi : -0.7, epoch: 20000, loss: 0.6818164
# phi : -0.7, epoch: 25000, loss: 0.685835
# phi : -0.7, epoch: 30000, loss: 0.6879142
# phi : -0.7, epoch: 35000, loss: 0.689171
# phi : -0.7, epoch: 40000, loss: 0.6899409
# phi : -0.7, epoch: 45000, loss: 0.6905184
# phi : -0.7, epoch: 50000, loss: 0.69092536
# phi : -0.7, epoch: 55000, loss: 0.6912088
# phi : -0.7, epoch: 60000, loss: 0.69146603
# phi : -0.7, epoch: 65000, loss: 0.6916583
# phi : -0.7, epoch: 70000, loss: 0.6917994
# phi : -0.7, epoch: 75000, loss: 0.6919185
# phi : -0.7, epoch: 80000, loss: 0.69201785
# phi : -0.7, epoch: 85000, loss: 0.69213116
# phi : -0.7, epoch: 90000, loss: 0.6922033
# phi : -0.7, epoch: 95000, loss: 0.6922793
# Training discriminator for phi: -0.6
#
# phi : -0.6, epoch: 0, loss: -0.0019578934
# phi : -0.6, epoch: 5000, loss: 0.39220265
# phi : -0.6, epoch: 10000, loss: 0.6406675
# phi : -0.6, epoch: 15000, loss: 0.6733014
# phi : -0.6, epoch: 20000, loss: 0.6822899
# phi : -0.6, epoch: 25000, loss: 0.6860579
# phi : -0.6, epoch: 30000, loss: 0.68806064
# phi : -0.6, epoch: 35000, loss: 0.6891905
# phi : -0.6, epoch: 40000, loss: 0.6899737
# phi : -0.6, epoch: 45000, loss: 0.6905135
# phi : -0.6, epoch: 50000, loss: 0.6909139
# phi : -0.6, epoch: 55000, loss: 0.6911617
# phi : -0.6, epoch: 60000, loss: 0.69140244
# phi : -0.6, epoch: 65000, loss: 0.6916154
# phi : -0.6, epoch: 70000, loss: 0.69178337
# phi : -0.6, epoch: 75000, loss: 0.691898
# phi : -0.6, epoch: 80000, loss: 0.69199455
# phi : -0.6, epoch: 85000, loss: 0.6920895
# phi : -0.6, epoch: 90000, loss: 0.6922088
# phi : -0.6, epoch: 95000, loss: 0.6922509
# Training discriminator for phi: -0.5
#
# phi : -0.5, epoch: 0, loss: 0.0011326075
# phi : -0.5, epoch: 5000, loss: 0.06587505
# phi : -0.5, epoch: 10000, loss: 0.32470816
# phi : -0.5, epoch: 15000, loss: 0.6103742
# phi : -0.5, epoch: 20000, loss: 0.6645679
# phi : -0.5, epoch: 25000, loss: 0.6783852
# phi : -0.5, epoch: 30000, loss: 0.68374383
# phi : -0.5, epoch: 35000, loss: 0.6864922
# phi : -0.5, epoch: 40000, loss: 0.6880565
# phi : -0.5, epoch: 45000, loss: 0.68907434
# phi : -0.5, epoch: 50000, loss: 0.6898009
# phi : -0.5, epoch: 55000, loss: 0.6903138
# phi : -0.5, epoch: 60000, loss: 0.69072163
# phi : -0.5, epoch: 65000, loss: 0.6910173
# phi : -0.5, epoch: 70000, loss: 0.6912676
# phi : -0.5, epoch: 75000, loss: 0.6914687
# phi : -0.5, epoch: 80000, loss: 0.69163275
# phi : -0.5, epoch: 85000, loss: 0.6917602
# phi : -0.5, epoch: 90000, loss: 0.69187075
# phi : -0.5, epoch: 95000, loss: 0.69197124
# Training discriminator for phi: -0.4
#
# phi : -0.4, epoch: 0, loss: -0.0046545267
# phi : -0.4, epoch: 5000, loss: 0.047685385
# phi : -0.4, epoch: 10000, loss: 0.19194697
# phi : -0.4, epoch: 15000, loss: 0.5052519
# phi : -0.4, epoch: 20000, loss: 0.6348436
# phi : -0.4, epoch: 25000, loss: 0.6662775
# phi : -0.4, epoch: 30000, loss: 0.67730016
# phi : -0.4, epoch: 35000, loss: 0.6825097
# phi : -0.4, epoch: 40000, loss: 0.6852496
# phi : -0.4, epoch: 45000, loss: 0.6870032
# phi : -0.4, epoch: 50000, loss: 0.6881571
# phi : -0.4, epoch: 55000, loss: 0.68898803
# phi : -0.4, epoch: 60000, loss: 0.68963015
# phi : -0.4, epoch: 65000, loss: 0.69010204
# phi : -0.4, epoch: 70000, loss: 0.69046444
# phi : -0.4, epoch: 75000, loss: 0.69079256
# phi : -0.4, epoch: 80000, loss: 0.6910135
# phi : -0.4, epoch: 85000, loss: 0.6912324
# phi : -0.4, epoch: 90000, loss: 0.69139856
# phi : -0.4, epoch: 95000, loss: 0.6915371
# Training discriminator for phi: -0.3
#
# phi : -0.3, epoch: 0, loss: -0.009981066
# phi : -0.3, epoch: 5000, loss: 0.037900448
# phi : -0.3, epoch: 10000, loss: 0.14634484
# phi : -0.3, epoch: 15000, loss: 0.4221617
# phi : -0.3, epoch: 20000, loss: 0.60825795
# phi : -0.3, epoch: 25000, loss: 0.6572005
# phi : -0.3, epoch: 30000, loss: 0.67311996
# phi : -0.3, epoch: 35000, loss: 0.6800527
# phi : -0.3, epoch: 40000, loss: 0.6837274
# phi : -0.3, epoch: 45000, loss: 0.68587774
# phi : -0.3, epoch: 50000, loss: 0.68735564
# phi : -0.3, epoch: 55000, loss: 0.68835175
# phi : -0.3, epoch: 60000, loss: 0.6890962
# phi : -0.3, epoch: 65000, loss: 0.68964654
# phi : -0.3, epoch: 70000, loss: 0.69007903
# phi : -0.3, epoch: 75000, loss: 0.69043696
# phi : -0.3, epoch: 80000, loss: 0.6907319
# phi : -0.3, epoch: 85000, loss: 0.69094884
# phi : -0.3, epoch: 90000, loss: 0.69115525
# phi : -0.3, epoch: 95000, loss: 0.69132024
# Training discriminator for phi: -0.2
#
# phi : -0.2, epoch: 0, loss: 0.0028376281
# phi : -0.2, epoch: 5000, loss: 0.021995753
# phi : -0.2, epoch: 10000, loss: 0.057308257
# phi : -0.2, epoch: 15000, loss: 0.14481711
# phi : -0.2, epoch: 20000, loss: 0.3386648
# phi : -0.2, epoch: 25000, loss: 0.5412798
# phi : -0.2, epoch: 30000, loss: 0.62750673
# phi : -0.2, epoch: 35000, loss: 0.6578272
# phi : -0.2, epoch: 40000, loss: 0.6708722
# phi : -0.2, epoch: 45000, loss: 0.67760056
# phi : -0.2, epoch: 50000, loss: 0.6814884
# phi : -0.2, epoch: 55000, loss: 0.68390816
# phi : -0.2, epoch: 60000, loss: 0.68561167
# phi : -0.2, epoch: 65000, loss: 0.6868762
# phi : -0.2, epoch: 70000, loss: 0.6878131
# phi : -0.2, epoch: 75000, loss: 0.6885219
# phi : -0.2, epoch: 80000, loss: 0.6890694
# phi : -0.2, epoch: 85000, loss: 0.6895046
# phi : -0.2, epoch: 90000, loss: 0.6898778
# phi : -0.2, epoch: 95000, loss: 0.6901839
# Training discriminator for phi: -0.1
#
# phi : -0.1, epoch: 0, loss: 0.0051836073
# phi : -0.1, epoch: 5000, loss: 0.009652555
# phi : -0.1, epoch: 10000, loss: 0.01661411
# phi : -0.1, epoch: 15000, loss: 0.027011871
# phi : -0.1, epoch: 20000, loss: 0.04434809
# phi : -0.1, epoch: 25000, loss: 0.07429579
# phi : -0.1, epoch: 30000, loss: 0.1286338
# phi : -0.1, epoch: 35000, loss: 0.22522466
# phi : -0.1, epoch: 40000, loss: 0.36390567
# phi : -0.1, epoch: 45000, loss: 0.4989708
# phi : -0.1, epoch: 50000, loss: 0.5839897
# phi : -0.1, epoch: 55000, loss: 0.6273667
# phi : -0.1, epoch: 60000, loss: 0.6498684
# phi : -0.1, epoch: 65000, loss: 0.662418
# phi : -0.1, epoch: 70000, loss: 0.66997135
# phi : -0.1, epoch: 75000, loss: 0.6750449
# phi : -0.1, epoch: 80000, loss: 0.6784224
# phi : -0.1, epoch: 85000, loss: 0.6808787
# phi : -0.1, epoch: 90000, loss: 0.6827456
# phi : -0.1, epoch: 95000, loss: 0.68417746
# Training discriminator for phi: 0.0
#
# phi : 0.0, epoch: 0, loss: -0.00085502863
# phi : 0.0, epoch: 5000, loss: -4.5090914e-05
# phi : 0.0, epoch: 10000, loss: 3.954768e-05
# phi : 0.0, epoch: 15000, loss: -2.0861626e-06
# phi : 0.0, epoch: 20000, loss: 1.9729137e-05
# phi : 0.0, epoch: 25000, loss: 2.7298927e-05
# phi : 0.0, epoch: 30000, loss: 2.7805567e-05
# phi : 0.0, epoch: 35000, loss: -5.429983e-05
# phi : 0.0, epoch: 40000, loss: 1.424551e-05
# phi : 0.0, epoch: 45000, loss: -2.5510788e-05
# phi : 0.0, epoch: 50000, loss: 6.952882e-05
# phi : 0.0, epoch: 55000, loss: -1.770258e-05
# phi : 0.0, epoch: 60000, loss: 9.804964e-06
# phi : 0.0, epoch: 65000, loss: 1.8775463e-05
# phi : 0.0, epoch: 70000, loss: 1.9460917e-05
# phi : 0.0, epoch: 75000, loss: 1.129508e-05
# phi : 0.0, epoch: 80000, loss: 2.9057264e-05
# phi : 0.0, epoch: 85000, loss: 3.0636787e-05
# phi : 0.0, epoch: 90000, loss: 5.441904e-05
# phi : 0.0, epoch: 95000, loss: -1.8537045e-05
# Training discriminator for phi: 0.1
#
# phi : 0.1, epoch: 0, loss: -0.0018966496
# phi : 0.1, epoch: 5000, loss: 0.0009676814
# phi : 0.1, epoch: 10000, loss: 0.002707541
# phi : 0.1, epoch: 15000, loss: 0.0048110485
# phi : 0.1, epoch: 20000, loss: 0.0076563656
# phi : 0.1, epoch: 25000, loss: 0.011819571
# phi : 0.1, epoch: 30000, loss: 0.018157363
# phi : 0.1, epoch: 35000, loss: 0.02794528
# phi : 0.1, epoch: 40000, loss: 0.044884592
# phi : 0.1, epoch: 45000, loss: 0.075121045
# phi : 0.1, epoch: 50000, loss: 0.12926665
# phi : 0.1, epoch: 55000, loss: 0.22296757
# phi : 0.1, epoch: 60000, loss: 0.3609949
# phi : 0.1, epoch: 65000, loss: 0.49608555
# phi : 0.1, epoch: 70000, loss: 0.58219284
# phi : 0.1, epoch: 75000, loss: 0.6259844
# phi : 0.1, epoch: 80000, loss: 0.6490773
# phi : 0.1, epoch: 85000, loss: 0.6618566
# phi : 0.1, epoch: 90000, loss: 0.66976273
# phi : 0.1, epoch: 95000, loss: 0.674804
# Training discriminator for phi: 0.2
#
# phi : 0.2, epoch: 0, loss: -0.0052067637
# phi : 0.2, epoch: 5000, loss: 0.010573536
# phi : 0.2, epoch: 10000, loss: 0.027213126
# phi : 0.2, epoch: 15000, loss: 0.064846694
# phi : 0.2, epoch: 20000, loss: 0.16552746
# phi : 0.2, epoch: 25000, loss: 0.38043135
# phi : 0.2, epoch: 30000, loss: 0.56659484
# phi : 0.2, epoch: 35000, loss: 0.6364417
# phi : 0.2, epoch: 40000, loss: 0.6615855
# phi : 0.2, epoch: 45000, loss: 0.6728081
# phi : 0.2, epoch: 50000, loss: 0.67867106
# phi : 0.2, epoch: 55000, loss: 0.6822027
# phi : 0.2, epoch: 60000, loss: 0.68449014
# phi : 0.2, epoch: 65000, loss: 0.68606144
# phi : 0.2, epoch: 70000, loss: 0.6871789
# phi : 0.2, epoch: 75000, loss: 0.68803424
# phi : 0.2, epoch: 80000, loss: 0.6886934
# phi : 0.2, epoch: 85000, loss: 0.6892193
# phi : 0.2, epoch: 90000, loss: 0.6896497
# phi : 0.2, epoch: 95000, loss: 0.6899893
# Training discriminator for phi: 0.3
#
# phi : 0.3, epoch: 0, loss: 0.0073911846
# phi : 0.3, epoch: 5000, loss: 0.05704689
# phi : 0.3, epoch: 10000, loss: 0.23625715
# phi : 0.3, epoch: 15000, loss: 0.52934796
# phi : 0.3, epoch: 20000, loss: 0.636649
# phi : 0.3, epoch: 25000, loss: 0.6655708
# phi : 0.3, epoch: 30000, loss: 0.6762897
# phi : 0.3, epoch: 35000, loss: 0.6816218
# phi : 0.3, epoch: 40000, loss: 0.68460846
# phi : 0.3, epoch: 45000, loss: 0.68642783
# phi : 0.3, epoch: 50000, loss: 0.6876986
# phi : 0.3, epoch: 55000, loss: 0.68862116
# phi : 0.3, epoch: 60000, loss: 0.6892407
# phi : 0.3, epoch: 65000, loss: 0.6897992
# phi : 0.3, epoch: 70000, loss: 0.6901713
# phi : 0.3, epoch: 75000, loss: 0.6904959
# phi : 0.3, epoch: 80000, loss: 0.6907642
# phi : 0.3, epoch: 85000, loss: 0.6909827
# phi : 0.3, epoch: 90000, loss: 0.69118774
# phi : 0.3, epoch: 95000, loss: 0.69133395
# Training discriminator for phi: 0.4
#
# phi : 0.4, epoch: 0, loss: 0.008947313
# phi : 0.4, epoch: 5000, loss: 0.09715772
# phi : 0.4, epoch: 10000, loss: 0.38310277
# phi : 0.4, epoch: 15000, loss: 0.60754675
# phi : 0.4, epoch: 20000, loss: 0.66004586
# phi : 0.4, epoch: 25000, loss: 0.67511034
# phi : 0.4, epoch: 30000, loss: 0.6815676
# phi : 0.4, epoch: 35000, loss: 0.68486094
# phi : 0.4, epoch: 40000, loss: 0.68682617
# phi : 0.4, epoch: 45000, loss: 0.6880553
# phi : 0.4, epoch: 50000, loss: 0.6890012
# phi : 0.4, epoch: 55000, loss: 0.6896422
# phi : 0.4, epoch: 60000, loss: 0.6901348
# phi : 0.4, epoch: 65000, loss: 0.69047344
# phi : 0.4, epoch: 70000, loss: 0.6908297
# phi : 0.4, epoch: 75000, loss: 0.6910563
# phi : 0.4, epoch: 80000, loss: 0.69125164
# phi : 0.4, epoch: 85000, loss: 0.6914453
# phi : 0.4, epoch: 90000, loss: 0.6915655
# phi : 0.4, epoch: 95000, loss: 0.6916923
# Training discriminator for phi: 0.5
#
# phi : 0.5, epoch: 0, loss: -0.018055737
# phi : 0.5, epoch: 5000, loss: 0.13857472
# phi : 0.5, epoch: 10000, loss: 0.52171874
# phi : 0.5, epoch: 15000, loss: 0.651004
# phi : 0.5, epoch: 20000, loss: 0.67441374
# phi : 0.5, epoch: 25000, loss: 0.6823025
# phi : 0.5, epoch: 30000, loss: 0.6857394
# phi : 0.5, epoch: 35000, loss: 0.68766505
# phi : 0.5, epoch: 40000, loss: 0.6888837
# phi : 0.5, epoch: 45000, loss: 0.6896529
# phi : 0.5, epoch: 50000, loss: 0.6902074
# phi : 0.5, epoch: 55000, loss: 0.6906668
# phi : 0.5, epoch: 60000, loss: 0.6909803
# phi : 0.5, epoch: 65000, loss: 0.69122833
# phi : 0.5, epoch: 70000, loss: 0.6914397
# phi : 0.5, epoch: 75000, loss: 0.6916189
# phi : 0.5, epoch: 80000, loss: 0.6917368
# phi : 0.5, epoch: 85000, loss: 0.691862
# phi : 0.5, epoch: 90000, loss: 0.69198537
# phi : 0.5, epoch: 95000, loss: 0.6920621
# Training discriminator for phi: 0.6
#
# phi : 0.6, epoch: 0, loss: -0.0019644499
# phi : 0.6, epoch: 5000, loss: 0.144654
# phi : 0.6, epoch: 10000, loss: 0.5542432
# phi : 0.6, epoch: 15000, loss: 0.6583994
# phi : 0.6, epoch: 20000, loss: 0.6770211
# phi : 0.6, epoch: 25000, loss: 0.6836314
# phi : 0.6, epoch: 30000, loss: 0.6865655
# phi : 0.6, epoch: 35000, loss: 0.68825436
# phi : 0.6, epoch: 40000, loss: 0.68929267
# phi : 0.6, epoch: 45000, loss: 0.6900229
# phi : 0.6, epoch: 50000, loss: 0.69050807
# phi : 0.6, epoch: 55000, loss: 0.69084495
# phi : 0.6, epoch: 60000, loss: 0.6911413
# phi : 0.6, epoch: 65000, loss: 0.6914123
# phi : 0.6, epoch: 70000, loss: 0.69159037
# phi : 0.6, epoch: 75000, loss: 0.69173056
# phi : 0.6, epoch: 80000, loss: 0.6918714
# phi : 0.6, epoch: 85000, loss: 0.6919628
# phi : 0.6, epoch: 90000, loss: 0.6920628
# phi : 0.6, epoch: 95000, loss: 0.6921566
# Training discriminator for phi: 0.7
#
# phi : 0.7, epoch: 0, loss: -0.0002194047
# phi : 0.7, epoch: 5000, loss: 0.22866237
# phi : 0.7, epoch: 10000, loss: 0.611054
# phi : 0.7, epoch: 15000, loss: 0.6685405
# phi : 0.7, epoch: 20000, loss: 0.6805244
# phi : 0.7, epoch: 25000, loss: 0.68534404
# phi : 0.7, epoch: 30000, loss: 0.6876378
# phi : 0.7, epoch: 35000, loss: 0.68882823
# phi : 0.7, epoch: 40000, loss: 0.68965375
# phi : 0.7, epoch: 45000, loss: 0.69037074
# phi : 0.7, epoch: 50000, loss: 0.6908317
# phi : 0.7, epoch: 55000, loss: 0.6911215
# phi : 0.7, epoch: 60000, loss: 0.6913415
# phi : 0.7, epoch: 65000, loss: 0.6915702
# phi : 0.7, epoch: 70000, loss: 0.6917149
# phi : 0.7, epoch: 75000, loss: 0.69188935
# phi : 0.7, epoch: 80000, loss: 0.6919733
# phi : 0.7, epoch: 85000, loss: 0.69207543
# phi : 0.7, epoch: 90000, loss: 0.69217837
# phi : 0.7, epoch: 95000, loss: 0.6922452
# Training discriminator for phi: 0.8
#
# phi : 0.8, epoch: 0, loss: -0.016732782
# phi : 0.8, epoch: 5000, loss: 0.37572092
# phi : 0.8, epoch: 10000, loss: 0.6454086
# phi : 0.8, epoch: 15000, loss: 0.6760572
# phi : 0.8, epoch: 20000, loss: 0.6838383
# phi : 0.8, epoch: 25000, loss: 0.6869895
# phi : 0.8, epoch: 30000, loss: 0.6886329
# phi : 0.8, epoch: 35000, loss: 0.68965626
# phi : 0.8, epoch: 40000, loss: 0.6903384
# phi : 0.8, epoch: 45000, loss: 0.6907451
# phi : 0.8, epoch: 50000, loss: 0.6911584
# phi : 0.8, epoch: 55000, loss: 0.6914332
# phi : 0.8, epoch: 60000, loss: 0.69163126
# phi : 0.8, epoch: 65000, loss: 0.69179744
# phi : 0.8, epoch: 70000, loss: 0.69191957
# phi : 0.8, epoch: 75000, loss: 0.69203407
# phi : 0.8, epoch: 80000, loss: 0.6921282
# phi : 0.8, epoch: 85000, loss: 0.6922299
# phi : 0.8, epoch: 90000, loss: 0.6922987
# phi : 0.8, epoch: 95000, loss: 0.69236106
# Training discriminator for phi: 0.9
#
# phi : 0.9, epoch: 0, loss: -0.00025492907
# phi : 0.9, epoch: 5000, loss: 0.42627198
# phi : 0.9, epoch: 10000, loss: 0.6541467
# phi : 0.9, epoch: 15000, loss: 0.67872685
# phi : 0.9, epoch: 20000, loss: 0.68490916
# phi : 0.9, epoch: 25000, loss: 0.68769205
# phi : 0.9, epoch: 30000, loss: 0.6890559
# phi : 0.9, epoch: 35000, loss: 0.6900089
# phi : 0.9, epoch: 40000, loss: 0.690599
# phi : 0.9, epoch: 45000, loss: 0.6910331
# phi : 0.9, epoch: 50000, loss: 0.6913717
# phi : 0.9, epoch: 55000, loss: 0.6915826
# phi : 0.9, epoch: 60000, loss: 0.69176215
# phi : 0.9, epoch: 65000, loss: 0.69191974
# phi : 0.9, epoch: 70000, loss: 0.6920469
# phi : 0.9, epoch: 75000, loss: 0.692112
# phi : 0.9, epoch: 80000, loss: 0.69222254
# phi : 0.9, epoch: 85000, loss: 0.6922952
# phi : 0.9, epoch: 90000, loss: 0.6923572
# phi : 0.9, epoch: 95000, loss: 0.69241846
# Training discriminator for phi: 1.0
#
# phi : 1.0, epoch: 0, loss: 0.008613348
# phi : 1.0, epoch: 5000, loss: 0.55740964
# phi : 1.0, epoch: 10000, loss: 0.6686644
# phi : 1.0, epoch: 15000, loss: 0.6824441
# phi : 1.0, epoch: 20000, loss: 0.686705
# phi : 1.0, epoch: 25000, loss: 0.6886834
# phi : 1.0, epoch: 30000, loss: 0.68984056
# phi : 1.0, epoch: 35000, loss: 0.69051176
# phi : 1.0, epoch: 40000, loss: 0.6909796
# phi : 1.0, epoch: 45000, loss: 0.6913224
# phi : 1.0, epoch: 50000, loss: 0.6916067
# phi : 1.0, epoch: 55000, loss: 0.6917875
# phi : 1.0, epoch: 60000, loss: 0.69194245
# phi : 1.0, epoch: 65000, loss: 0.6920884
# phi : 1.0, epoch: 70000, loss: 0.6921825
# phi : 1.0, epoch: 75000, loss: 0.69224966
# phi : 1.0, epoch: 80000, loss: 0.6923286
# phi : 1.0, epoch: 85000, loss: 0.6924017
# phi : 1.0, epoch: 90000, loss: 0.69243205
# phi : 1.0, epoch: 95000, loss: 0.6924958
#
# Done All training

# %%
plt.scatter(phi,js_d)
plt.xlabel('Parameter phi')
plt.ylabel('Estimated Jensen Shannon Divergence')
plt.title('Discriminator trained for 100 000 epochs')
plt.savefig('/content/gdrive/My Drive/Q1_3_JSD.png')

# %%
def WD(Tx,Ty,GP,lam):
  return Tx.mean()-Ty.mean()-lam*GP

def GP_func(C,x,y):
  a=torch.FloatTensor(np.random.uniform(0, 1, (Tx.size()[0], 1))).to(device)
  z=a*x+(1-a)*y
  z= torch.autograd.Variable(z, requires_grad=True)
  Tz=C(z)
  gradients = torch.autograd.grad(Tz,z,grad_outputs= torch.ones(Tz.size()).to(device),create_graph=True, retain_graph=True, only_inputs=True) 
  return ((gradients[0].norm(2, dim=1)-1)**2).mean()

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(2, 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, 1)
    
    def forward(self, x):
#         x = x.view(-1, 512)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
    def name(self):
        return "MLP"

# %%
phi=np.round(np.linspace(-1,1,21),2)
wd_d=np.zeros(phi.shape)
n_epochs = 50000
lr = 0.001
lam=10
for i in range(len(phi)):
  print('\nTraining discriminator for phi: ' + str(phi[i])+'\n')
  C = MLP().to(device)
  optimizer = torch.optim.SGD(C.parameters(), lr=lr)
  for epoch in range(n_epochs):
    optimizer.zero_grad()
    x = torch.FloatTensor(next(distribution1(0))).to(device)
    y = torch.FloatTensor(next(distribution1(phi[i]))).to(device)
    GP=GP_func(C,x,y)
    optimizer.zero_grad()
    Tx=C(x)
    Ty=C(y)
    loss=-WD(Tx,Ty,GP,lam)
    loss.backward()
    optimizer.step()
    if epoch % 5000 == 0:
      print('phi : ' + str(0) + ', epoch: ' + str(epoch) +', loss: '+str(-loss.cpu().data.numpy()))
  print('phi : ' + str(0) + ', epoch: ' + str(epoch) +', loss: '+str(-loss.cpu().data.numpy()))
  wd_d[i]=-loss.cpu().data.numpy()
    
print('\nDone All training')
# Out:
# Training discriminator for phi: -1.0
#
# phi : 0, epoch: 0, loss: -8.234832
# phi : 0, epoch: 5000, loss: 1.0244508
# phi : 0, epoch: 10000, loss: 1.0240995
# phi : 0, epoch: 15000, loss: 1.0252436
# phi : 0, epoch: 20000, loss: 1.025073
# phi : 0, epoch: 25000, loss: 1.0248928
# phi : 0, epoch: 30000, loss: 1.0239294
# phi : 0, epoch: 35000, loss: 1.025026
# phi : 0, epoch: 40000, loss: 1.0250134
# phi : 0, epoch: 45000, loss: 1.0251172
# phi : 0, epoch: 49999, loss: 1.0250058
#
# Training discriminator for phi: -0.9
#
# phi : 0, epoch: 0, loss: -7.8236275
# phi : 0, epoch: 5000, loss: 0.91857195
# phi : 0, epoch: 10000, loss: 0.92039555
# phi : 0, epoch: 15000, loss: 0.9209717
# phi : 0, epoch: 20000, loss: 0.91923946
# phi : 0, epoch: 25000, loss: 0.9204255
# phi : 0, epoch: 30000, loss: 0.9199629
# phi : 0, epoch: 35000, loss: 0.9200174
# phi : 0, epoch: 40000, loss: 0.91998845
# phi : 0, epoch: 45000, loss: 0.92019033
# phi : 0, epoch: 49999, loss: 0.9202467
#
# Training discriminator for phi: -0.8
#
# phi : 0, epoch: 0, loss: -9.13292
# phi : 0, epoch: 5000, loss: 0.8155776
# phi : 0, epoch: 10000, loss: 0.81601226
# phi : 0, epoch: 15000, loss: 0.8163898
# phi : 0, epoch: 20000, loss: 0.8158425
# phi : 0, epoch: 25000, loss: 0.81592894
# phi : 0, epoch: 30000, loss: 0.8165235
# phi : 0, epoch: 35000, loss: 0.8159613
# phi : 0, epoch: 40000, loss: 0.8161945
# phi : 0, epoch: 45000, loss: 0.8160821
# phi : 0, epoch: 49999, loss: 0.816232
#
# Training discriminator for phi: -0.7
#
# phi : 0, epoch: 0, loss: -7.8460994
# phi : 0, epoch: 5000, loss: 0.7116625
# phi : 0, epoch: 10000, loss: 0.7128358
# phi : 0, epoch: 15000, loss: 0.7120888
# phi : 0, epoch: 20000, loss: 0.7125297
# phi : 0, epoch: 25000, loss: 0.71250886
# phi : 0, epoch: 30000, loss: 0.7120133
# phi : 0, epoch: 35000, loss: 0.71261096
# phi : 0, epoch: 40000, loss: 0.7128167
# phi : 0, epoch: 45000, loss: 0.71218413
# phi : 0, epoch: 49999, loss: 0.71208704
#
# Training discriminator for phi: -0.6
#
# phi : 0, epoch: 0, loss: -8.052777
# phi : 0, epoch: 5000, loss: 0.6084511
# phi : 0, epoch: 10000, loss: 0.6090062
# phi : 0, epoch: 15000, loss: 0.6093864
# phi : 0, epoch: 20000, loss: 0.60905975
# phi : 0, epoch: 25000, loss: 0.6090915
# phi : 0, epoch: 30000, loss: 0.6090451
# phi : 0, epoch: 35000, loss: 0.60885733
# phi : 0, epoch: 40000, loss: 0.6088877
# phi : 0, epoch: 45000, loss: 0.6089268
# phi : 0, epoch: 49999, loss: 0.6089364
#
# Training discriminator for phi: -0.5
#
# phi : 0, epoch: 0, loss: -9.120657
# phi : 0, epoch: 5000, loss: 0.50629956
# phi : 0, epoch: 10000, loss: 0.5050422
# phi : 0, epoch: 15000, loss: 0.5056648
# phi : 0, epoch: 20000, loss: 0.5061249
# phi : 0, epoch: 25000, loss: 0.5063352
# phi : 0, epoch: 30000, loss: 0.50626487
# phi : 0, epoch: 35000, loss: 0.5062646
# phi : 0, epoch: 40000, loss: 0.50637954
# phi : 0, epoch: 45000, loss: 0.50634307
# phi : 0, epoch: 49999, loss: 0.5062153
#
# Training discriminator for phi: -0.4
#
# phi : 0, epoch: 0, loss: -8.528819
# phi : 0, epoch: 5000, loss: 0.3954031
# phi : 0, epoch: 10000, loss: 0.40356776
# phi : 0, epoch: 15000, loss: 0.40423936
# phi : 0, epoch: 20000, loss: 0.4040206
# phi : 0, epoch: 25000, loss: 0.40418297
# phi : 0, epoch: 30000, loss: 0.4042584
# phi : 0, epoch: 35000, loss: 0.40382203
# phi : 0, epoch: 40000, loss: 0.40411353
# phi : 0, epoch: 45000, loss: 0.40405655
# phi : 0, epoch: 49999, loss: 0.40388912
#
# Training discriminator for phi: -0.3
#
# phi : 0, epoch: 0, loss: -8.741263
# phi : 0, epoch: 5000, loss: 0.30117825
# phi : 0, epoch: 10000, loss: 0.30186096
# phi : 0, epoch: 15000, loss: 0.30244246
# phi : 0, epoch: 20000, loss: 0.30179837
# phi : 0, epoch: 25000, loss: 0.3017884
# phi : 0, epoch: 30000, loss: 0.302275
# phi : 0, epoch: 35000, loss: 0.30230784
# phi : 0, epoch: 40000, loss: 0.3025872
# phi : 0, epoch: 45000, loss: 0.30181816
# phi : 0, epoch: 49999, loss: 0.30223963
#
# Training discriminator for phi: -0.2
#
# phi : 0, epoch: 0, loss: -8.497039
# phi : 0, epoch: 5000, loss: 0.17477873
# phi : 0, epoch: 10000, loss: 0.20163383
# phi : 0, epoch: 15000, loss: 0.20096911
# phi : 0, epoch: 20000, loss: 0.20104548
# phi : 0, epoch: 25000, loss: 0.20099296
# phi : 0, epoch: 30000, loss: 0.2009948
# phi : 0, epoch: 35000, loss: 0.20097905
# phi : 0, epoch: 40000, loss: 0.20094262
# phi : 0, epoch: 45000, loss: 0.20101166
# phi : 0, epoch: 49999, loss: 0.2009841
#
# Training discriminator for phi: -0.1
#
# phi : 0, epoch: 0, loss: -8.929955
# phi : 0, epoch: 5000, loss: 0.09384947
# phi : 0, epoch: 10000, loss: 0.09518285
# phi : 0, epoch: 15000, loss: 0.09611479
# phi : 0, epoch: 20000, loss: 0.09979214
# phi : 0, epoch: 25000, loss: 0.099749796
# phi : 0, epoch: 30000, loss: 0.10004053
# phi : 0, epoch: 35000, loss: 0.10002624
# phi : 0, epoch: 40000, loss: 0.100203454
# phi : 0, epoch: 45000, loss: 0.100355074
# phi : 0, epoch: 49999, loss: 0.10025152
#
# Training discriminator for phi: 0.0
#
# phi : 0, epoch: 0, loss: -8.470039
# phi : 0, epoch: 5000, loss: -0.0062674684
# phi : 0, epoch: 10000, loss: -0.0031801008
# phi : 0, epoch: 15000, loss: -0.022627952
# phi : 0, epoch: 20000, loss: -0.013630963
# phi : 0, epoch: 25000, loss: 0.0064449906
# phi : 0, epoch: 30000, loss: 0.023125855
# phi : 0, epoch: 35000, loss: 0.009152096
# phi : 0, epoch: 40000, loss: -0.019536603
# phi : 0, epoch: 45000, loss: -0.002907038
# phi : 0, epoch: 49999, loss: -0.009696412
#
# Training discriminator for phi: 0.1
#
# phi : 0, epoch: 0, loss: -9.231778
# phi : 0, epoch: 5000, loss: 0.09854109
# phi : 0, epoch: 10000, loss: 0.09995805
# phi : 0, epoch: 15000, loss: 0.10016485
# phi : 0, epoch: 20000, loss: 0.10030741
# phi : 0, epoch: 25000, loss: 0.10029312
# phi : 0, epoch: 30000, loss: 0.1002524
# phi : 0, epoch: 35000, loss: 0.10027292
# phi : 0, epoch: 40000, loss: 0.10022943
# phi : 0, epoch: 45000, loss: 0.1002319
# phi : 0, epoch: 49999, loss: 0.100230075
#
# Training discriminator for phi: 0.2
#
# phi : 0, epoch: 0, loss: -8.852772
# phi : 0, epoch: 5000, loss: -0.09794814
# phi : 0, epoch: 10000, loss: 0.19786723
# phi : 0, epoch: 15000, loss: 0.19961196
# phi : 0, epoch: 20000, loss: 0.20112012
# phi : 0, epoch: 25000, loss: 0.20094097
# phi : 0, epoch: 30000, loss: 0.20101975
# phi : 0, epoch: 35000, loss: 0.20109288
# phi : 0, epoch: 40000, loss: 0.20109896
# phi : 0, epoch: 45000, loss: 0.20096573
# phi : 0, epoch: 49999, loss: 0.20101215
#
# Training discriminator for phi: 0.3
#
# phi : 0, epoch: 0, loss: -6.768981
# phi : 0, epoch: 5000, loss: 0.30193803
# phi : 0, epoch: 10000, loss: 0.30201238
# phi : 0, epoch: 15000, loss: 0.30229095
# phi : 0, epoch: 20000, loss: 0.3022646
# phi : 0, epoch: 25000, loss: 0.30228484
# phi : 0, epoch: 30000, loss: 0.302313
# phi : 0, epoch: 35000, loss: 0.30229214
# phi : 0, epoch: 40000, loss: 0.30223513
# phi : 0, epoch: 45000, loss: 0.3022807
# phi : 0, epoch: 49999, loss: 0.30228296
#
# Training discriminator for phi: 0.4
#
# phi : 0, epoch: 0, loss: -8.158115
# phi : 0, epoch: 5000, loss: 0.39502248
# phi : 0, epoch: 10000, loss: 0.40398893
# phi : 0, epoch: 15000, loss: 0.40444857
# phi : 0, epoch: 20000, loss: 0.4045415
# phi : 0, epoch: 25000, loss: 0.40444335
# phi : 0, epoch: 30000, loss: 0.4043655
# phi : 0, epoch: 35000, loss: 0.40393832
# phi : 0, epoch: 40000, loss: 0.40402544
# phi : 0, epoch: 45000, loss: 0.40430576
# phi : 0, epoch: 49999, loss: 0.40416324
#
# Training discriminator for phi: 0.5
#
# phi : 0, epoch: 0, loss: -6.835455
# phi : 0, epoch: 5000, loss: 0.5061143
# phi : 0, epoch: 10000, loss: 0.5063314
# phi : 0, epoch: 15000, loss: 0.5062821
# phi : 0, epoch: 20000, loss: 0.5061631
# phi : 0, epoch: 25000, loss: 0.5064004
# phi : 0, epoch: 30000, loss: 0.5064472
# phi : 0, epoch: 35000, loss: 0.5063749
# phi : 0, epoch: 40000, loss: 0.50682336
# phi : 0, epoch: 45000, loss: 0.50656146
# phi : 0, epoch: 49999, loss: 0.5062287
#
# Training discriminator for phi: 0.6
#
# phi : 0, epoch: 0, loss: -7.740695
# phi : 0, epoch: 5000, loss: 0.60957116
# phi : 0, epoch: 10000, loss: 0.6094505
# phi : 0, epoch: 15000, loss: 0.609422
# phi : 0, epoch: 20000, loss: 0.6093371
# phi : 0, epoch: 25000, loss: 0.6092606
# phi : 0, epoch: 30000, loss: 0.6093288
# phi : 0, epoch: 35000, loss: 0.6091968
# phi : 0, epoch: 40000, loss: 0.60908115
# phi : 0, epoch: 45000, loss: 0.60912865
# phi : 0, epoch: 49999, loss: 0.6091065
#
# Training discriminator for phi: 0.7
#
# phi : 0, epoch: 0, loss: -9.550921
# phi : 0, epoch: 5000, loss: 0.7100619
# phi : 0, epoch: 10000, loss: 0.71222645
# phi : 0, epoch: 15000, loss: 0.7122382
# phi : 0, epoch: 20000, loss: 0.71234286
# phi : 0, epoch: 25000, loss: 0.71230143
# phi : 0, epoch: 30000, loss: 0.71230423
# phi : 0, epoch: 35000, loss: 0.71230173
# phi : 0, epoch: 40000, loss: 0.7122709
# phi : 0, epoch: 45000, loss: 0.71229464
# phi : 0, epoch: 49999, loss: 0.7122819
#
# Training discriminator for phi: 0.8
#
# phi : 0, epoch: 0, loss: -7.6115584
# phi : 0, epoch: 5000, loss: 0.815052
# phi : 0, epoch: 10000, loss: 0.81685513
# phi : 0, epoch: 15000, loss: 0.8158766
# phi : 0, epoch: 20000, loss: 0.81613255
# phi : 0, epoch: 25000, loss: 0.81589186
# phi : 0, epoch: 30000, loss: 0.81590885
# phi : 0, epoch: 35000, loss: 0.8160352
# phi : 0, epoch: 40000, loss: 0.81600463
# phi : 0, epoch: 45000, loss: 0.8160013
# phi : 0, epoch: 49999, loss: 0.816002
#
# Training discriminator for phi: 0.9
#
# phi : 0, epoch: 0, loss: -8.150934
# phi : 0, epoch: 5000, loss: 0.9172321
# phi : 0, epoch: 10000, loss: 0.92094296
# phi : 0, epoch: 15000, loss: 0.92049336
# phi : 0, epoch: 20000, loss: 0.9206569
# phi : 0, epoch: 25000, loss: 0.92050743
# phi : 0, epoch: 30000, loss: 0.9202567
# phi : 0, epoch: 35000, loss: 0.9203395
# phi : 0, epoch: 40000, loss: 0.9206442
# phi : 0, epoch: 45000, loss: 0.9204042
# phi : 0, epoch: 49999, loss: 0.92037934
#
# Training discriminator for phi: 1.0
#
# phi : 0, epoch: 0, loss: -7.0476127
# phi : 0, epoch: 5000, loss: 1.0222516
# phi : 0, epoch: 10000, loss: 1.0239484
# phi : 0, epoch: 15000, loss: 1.0252806
# phi : 0, epoch: 20000, loss: 1.0255398
# phi : 0, epoch: 25000, loss: 1.0254018
# phi : 0, epoch: 30000, loss: 1.0253389
# phi : 0, epoch: 35000, loss: 1.0252843
# phi : 0, epoch: 40000, loss: 1.0257478
# phi : 0, epoch: 45000, loss: 1.0255297
# phi : 0, epoch: 49999, loss: 1.0252707
#
# Done All training

# %%
plt.scatter(phi,wd_d)
plt.xlabel('Parameter phi')
plt.ylabel('Estimated Wasserstein Distance')
plt.title('Critic trained for 50 000 epochs')
plt.savefig('/content/gdrive/My Drive/Q1_3_WD.png')

# %%
def JSD_2(Dx,Dy):
  return torch.mean(torch.log(Dy)) + torch.mean(torch.log(1 - Dx))

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(1, 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, 1)
    
    def forward(self, x):
#         x = x.view(-1, 512)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x
    
    def name(self):
        return "MLP"

# %%
n_epochs = 100000
lr = 0.001
D = MLP().to(device)
optimizer = torch.optim.SGD(D.parameters(), lr=lr)
for epoch in range(n_epochs):
  x_d = torch.FloatTensor(next(distribution3(512))).to(device)
  y_g = torch.FloatTensor(next(distribution4(512))).to(device)
  optimizer.zero_grad()
  Dx=D(x_d)
  Dy=D(y_g)
  loss =-JSD_2(Dx,Dy)
  loss.backward()
  optimizer.step()
  if epoch % 5000 == 0:
    print('epoch: ' + str(epoch) +', loss: '+str(-loss.cpu().data.numpy()))
      
print('\nDone All training')
# Out:
# epoch: 0, loss: -1.4034219
# epoch: 5000, loss: -1.2386776
# epoch: 10000, loss: -1.2347502
# epoch: 15000, loss: -1.1969967
# epoch: 20000, loss: -1.1990709
# epoch: 25000, loss: -1.1581612
# epoch: 30000, loss: -1.219418
# epoch: 35000, loss: -1.2296746
# epoch: 40000, loss: -1.2162559
# epoch: 45000, loss: -1.2243845
# epoch: 50000, loss: -1.2795925
# epoch: 55000, loss: -1.1617678
# epoch: 60000, loss: -1.2140567
# epoch: 65000, loss: -1.1686577
# epoch: 70000, loss: -1.147807
# epoch: 75000, loss: -1.1753765
# epoch: 80000, loss: -1.2305504
# epoch: 85000, loss: -1.172827
# epoch: 90000, loss: -1.2000915
# epoch: 95000, loss: -1.2368475
#
# Done All training

# %%
from __future__ import print_function
import numpy as np
import torch 
import matplotlib.pyplot as plt

# plot p0 and p1
plt.figure()

# empirical
xx = torch.randn(10000)
f = lambda x: torch.tanh(x*2+1) + x*0.75
d = lambda x: (1-torch.tanh(x*2+1)**2)*2+0.75
plt.hist(f(xx), 100, alpha=0.5, density=1)
plt.hist(xx, 100, alpha=0.5, density=1)
plt.xlim(-5,5)
# exact
xx = np.linspace(-5,5,1000)
N = lambda x: np.exp(-x**2/2.)/((2*np.pi)**0.5)
plt.plot(f(torch.from_numpy(xx)).numpy(), d(torch.from_numpy(xx)).numpy()**(-1)*N(xx))
plt.plot(xx, N(xx))

# %%
r = D(torch.FloatTensor(xx).to(device).unsqueeze(dim=1)).squeeze().cpu().data.numpy() # evaluate xx using your discriminator; replace xx with the output
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.plot(xx,r)
plt.title(r'$D(x)$')

# estimate the density of distribution4 (on xx) using the discriminator; 
                                # replace "np.ones_like(xx)*0." with your estimate
estimate=N(xx)*(r/(1-r))
plt.subplot(1,2,2)
plt.plot(xx,estimate)
plt.plot(f(torch.from_numpy(xx)).numpy(), d(torch.from_numpy(xx)).numpy()**(-1)*N(xx))
plt.legend(['Estimated','True'])
plt.title('Estimated vs True')

plt.savefig('/content/gdrive/My Drive/Q1_4_JSD.png')
